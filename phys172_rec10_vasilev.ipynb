# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidVasilev1/APCSP/blob/master/phys172_rec10_vasilev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # $\color{blue}{\text{RECITATION 10 : Energy Principle: Point Particle  &  Extended Systems}}$
#
# ---

# %% [markdown]
# ### $\color{orange}{\text{Last Name}}$

# %% [markdown]
# Vasilev

# %% [markdown]
# ### $\color{orange}{\text{First Name}}$

# %% [markdown]
# David

# %% [markdown]
# ### $\color{orange}{\text{Recitation Section DAY}}$

# %% [markdown]
# Thursday

# %% [markdown]
# ### $\color{orange}{\text{Recitation Section TIME}}$

# %% [markdown]
# 8:30

# %% [markdown]
# ### $\color{orange}{\text{Group Number}}$

# %% [markdown]
# 12

# %% [markdown]
# ### $\color{orange}{\text{Group Members}}$

# %% [markdown]
# Dhruv Gandhi, Eugene Hwang, Maurice Reimer, Hyunchae Kim

# %% [markdown]
# ---

# %% [markdown]
# ##<b>Problem 1:</b> Consider a bicycle wheel, radius $R$, with rim of mass $M$ and axle of mass $m$.  The masses of the wheel’s thin spokes are so small that we will neglect them. Initially, the wheel is resting on a horizontal surface, and you hold its axle, a hand on each side of the wheel, so that it doesn’t tip over.  At time t = 0s you exert a horizontal force of magnitude F on the axle so that the wheel begins to roll without slipping.
#
# ##**Part 1:** Determine the wheel’s speed when you have pushed it forward a distance $d$. $\color{red}{\text{[Hint:Rolling without slipping means $v_{CM}=\omega R$]}}$

# %% [markdown]
# <img src="https://raw.githubusercontent.com/phys172/fall2022/main/images/phys172_rec10_fig1.png" alt="AGV" height="200" width="400">

# %% [markdown]
# ---
#
#
# #**1.1	<font color="magenta">RECALL</font> a different problem from a lecture, homework, or quiz that utilizes the same principles/concepts, and you believe will have a similar solution strategy. <i><font color="green">Please describe the problem and state how it is similar to the recitation problem this week.</font></i>$\color{red}{\text{Note, you do not need to solve the problem.}}$**

# %% [markdown]
# This problem is similar to question 4 on homework 17. In this question there is a hoop that is rolling down a hill and given initial parameters, you need to find the final velocity of that hoop. The second part of this problem is where things get very similar, as we being to use a bicycle wheel.

# %% [markdown]
# ---
#
#
# #**1.2 What principle(s)/concept(s) will you need to help solve the problem?**

# %% [markdown]
# We would use rotational energy, the energy principle, translational and relative energy, angular velocity, and extended system.

# %% [markdown]
# ---
#
#
# #<b>1.3 What assumption(s)/approximation(s) do you need to make to better help you solve the problem?</b>

# %% [markdown]
# You can assume that the wheel never slips, this means that there is a frictional force. We can also assume that there are no other external forces acting upon the object. We also assume that $v<<c$ for the block. We also assume that all energy is conserved.

# %% [markdown]
# ---
#
#
# #**1.4 Identify your system (i.e. objects experiencing a change) and surroundings (i.e. objects causing the change).**

# %% [markdown]
# The system is the wheel and the surroundings is the floor and the you.

# %% [markdown]
# ---
# #**1.5 Will you use a point particle or extended system model? Explain your reasoning.**

# %% [markdown]
# We will use the extended model because the frictional force would have a distance of 0.

# %% [markdown]
# # $\color{blue}{\text{ON YOUR OWN SHEET OF PAPER DO THE FOLLOWING:}}$
#
# ---
#
#
# # $\color{red}{\text{Draw free body diagram(s) representing the situation.}}$
# # $\color{red}{\text{Solve the problem. Neatly and clearly show all steps in your solution.}}$
# # $\color{green}{\text{Insert the compressed photo(s) of your work directly below.}}$
# # $\color{blue}{\text{ONLY THEN continue with the questions below.}}$
#
# ---

# %% [markdown]
# # $\color{red}{\text{  Instructions to upload an image}}$
#
#
# *   Go to "**files**" (in the botton of the bar on the left side of the screen. Looks like a file folder)
# *   Click "**Upload to session storage**"
# *   Select the image of your work and upload.
# *   Click on the 3 dots to the right of your image and selecting "**Copy Path**"
# *   Replace "**PATH TO YOUR IMAGE**" with the path to your image by pasting in the path (don't delete quotation marks)
# *   Run the cell and the image should appear
# *   NOTE: **If your image needs resizing**, change the numbers in **"new_size=(600,700)"** until it all appears in the pdf.

# %%
from PIL import Image

img = Image.open('/content/IMG_7944.jpeg')
new_size=(600,700)
img=img.resize(new_size)
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x700>

# %% [markdown]
# ---
# #**Part 2:** Determine the magnitude of the friction force that the surface exerts on the wheel while you push it.

# %% [markdown]
# ---
#
#
# #**2.1 What principle(s)/concept(s) will you need to help solve the problem?**

# %% [markdown]
# You would use the energy principle for a point particle system.

# %% [markdown]
# ---
#
#
# #<b>2.2 What assumption(s)/approximation(s) do you need to make to better help you solve the problem?</b>

# %% [markdown]
# You can assume that the wheel never slips, this means that there is a frictional force. We can also assume that there are no other external forces acting upon the object. We also assume that  v<<c  for the block. We also assume that all energy is conserved.

# %% [markdown]
# ---
#
#
# #**2.3 Identify your system (i.e. objects experiencing a change) and surroundings (i.e. objects causing the change).**

# %% [markdown]
# The system is the wheel while the surroundings are the Earth and ground.

# %% [markdown]
# ---
# #**2.4 Will you use a point particle or extended system model? Explain your reasoning.**

# %% [markdown]
# You would use point particle because using the extended model would lead to the friction being 0, but in this case you are trying to solve for friction. Calculating using center of mass leads you to be able to account for friction.

# %% [markdown]
# # $\color{blue}{\text{ON YOUR OWN SHEET OF PAPER DO THE FOLLOWING:}}$
#
# ---
#
#
# # $\color{red}{\text{Draw free body diagram(s) representing the situation.}}$
# # $\color{red}{\text{Solve the problem. Neatly and clearly show all steps in your solution.}}$
# # $\color{green}{\text{Insert the compressed photo(s) of your work directly below.}}$
# # $\color{blue}{\text{ONLY THEN continue with the questions below.}}$
#
# ---

# %% [markdown]
# # $\color{red}{\text{  Instructions to upload an image}}$
#
#
# *   Go to "**files**" (in the botton of the bar on the left side of the screen. Looks like a file folder)
# *   Click "**Upload to session storage**"
# *   Select the image of your work and upload.
# *   Click on the 3 dots to the right of your image and selecting "**Copy Path**"
# *   Replace "**PATH TO YOUR IMAGE**" with the path to your image by pasting in the path (don't delete quotation marks)
# *   Run the cell and the image should appear
# *   NOTE: **If your image needs resizing**, change the numbers in **"new_size=(600,700)"** until it all appears in the pdf.

# %%
from PIL import Image

img = Image.open('/content/IMG_7944.jpeg')
new_size=(600,700)
img=img.resize(new_size)
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x700>

# %% [markdown]
# ---
# #**Write your answer for Part 1.**

# %% [markdown]
# $v=\sqrt\frac{2Fd}{2M+m}$

# %% [markdown]
# #**Write your answer for Part 2.**

# %% [markdown]
# $f=\frac{FM}{2M+m}$

# %% [markdown]
# ---
#
#
# ##**How confident are you about your answers?**
#
#
# *  Very Confident
# *  Slightly Confident
# *  Slightly Unconfident
# *  Very Confident

# %% [markdown]
# Very Confident

# %% [markdown]
# ---
# #**3.1 Does your answer seem appropriate? Why or why not?**

# %% [markdown]
# These answers seem appropriate because using the extended system to calculate for the velocity would make sense because of how using a system leads to the friction being 0 in relation to the movement. For the second part, using point particle approach leads to the friction being a value. Simplifying leads to both answers making sense in terms of their values.

# %% [markdown]
# ---
# #**3.2 Are there other ways to solve this problem? Explain how or why not.**

# %% [markdown]
# You could use the momentum principle to solve for the velocities and the forces acting upon the system.

# %% [markdown]
# ---
# # *A **scientific argument** consists of three pieces: $\color{red}{\text{CLAIM,}}$ $\color{green}{\text{EVIDENCE,}}$ and $\color{blue}{\text{REASONING}}$.*

# %% [markdown]
# ---
# # <i><font color="red">A <b>CLAIM</b> is every decision you took to solve the problem i.e. choice of principle/concept, system/surrounding, approximation/assumption, or key intermediate or final decisions/conclusions you found during your problem-solving strategy. It is an assertion that that the decision/conclusion was the right one to answer the key question(s) in the problem statement.</font></i>
#
# # <i><font color="green"><b>EVIDENCE</b> is the information either provided in the problem or something that you know (e.g. from the physics class) to be factually correct that helped you make the decision above.</font></i>
#
# # <i><font color = "blue"><b>REASONING</b></font> is an explanation of why the <font color = "green">EVIDENCE</font> supports the <font color="red">CLAIM</font>.</i>

# %% [markdown]
# #**3.3 In words, construct an argument to explain, elaborate and justify your solution (Parts 1 & 2).**

# %% [markdown]
# ---
#
# ### **What <font color="red">CLAIMS</font> support your solution?**

# %% [markdown]
# We use the energy principle. We assume that the velocity is much less than the speed of light. We assume that there are no other forces are acting upon the system. We use a extended system for the first part, and a point particle for the second.

# %% [markdown]
# ###**What <font color="green">EVIDENCE</font> supports your solution?**

# %% [markdown]
# The object's change in energy is equal to the total work done by the force acting upon it. The objects are not at relativistic speeds. The problem contains a closed system. There are multiple locations where forces are applied in Part 2, and there is only one location where forces are applied in Part 1. In part 2 the work done by friction is over a distance while the friction when the system is considered as an extended model is 0 in relation to the distance that has been traveled.

# %% [markdown]
# ###**What <font color="blue">REASONING</font> supports your solution?**

# %% [markdown]
# The object has both translational and rotational energy that when added together is equal to the work done by the forces acting upon the system, which in this case is the wheel. The box is going much slower than the speed of light to be experiencing relativistic effects. The problem does not mention or air resistance and only involves that the bicycle wheel is experiencing friction and th eapplied force. For Part 1, you are asked to find the Vcm, and to do so, you would need to factor in not just the translational energy and the Work, but also the rotational energy as well. In Part 2 however, you would just need the point at the center of mass as if you included rotational energy, the fictional force would end up being 0.

# %% [markdown]
# ---
#
# # <font color="magenta"><b><u>PLEASE RATE EACH STATEMENT BELOW</u>.</b></font><br>
# #1 (STRONGLY <b>DISAGREE</b>) -- 2 -- 3 -- 4 -- 5 -- 6 -- 7 (STRONGLY <b>AGREE</b>).<br>
# #Double-click (or enter) below each statement and type a number from **1** to **7**.
# #There are no right or wrong answers.<br>
# #Points will only be deducted if they are left blank.
#
# ---

# %% [markdown]
# ##<font color = "magenta">For this RECITATION, **I had to keep many things in mind simultaneously**.</font>

# %% [markdown]
# 6

# %% [markdown]
# ---
#
#
# ##<font color = "magenta">This RECITATION was **very complex**.</font>

# %% [markdown]
# 5

# %% [markdown]
# ---
#
#
# ##<font color = "magenta">I **made an effort**, not only to understand a number of details, but also **to understand the bigger picture** of this RECITATION.</font><br>

# %% [markdown]
# 7

# %% [markdown]
# ---
#
#
# ##<font color = "magenta">My **goal** while going through the RECITATION was to **understand everything correctl**y.</font>

# %% [markdown]
# 7

# %% [markdown]
# ---
#
#
# ##<font color = "magenta">The RECITATION included **many parts** that **supported my understanding** of the materials.</font><br>

# %% [markdown]
# 6

# %% [markdown]
# ---
#
#
# ##<font color = "magenta">During this RECITATION, it was **exhausting** just trying to **find the important information**.</font><br>

# %% [markdown]
# 2

# %% [markdown]
# ---
#
#
# ##<font color = "magenta">The **design** of this RECITATION made it **difficult** to learn the concepts.</font><br>

# %% [markdown]
# 1

# %% [markdown]
# ---
#
#
# ##<font color = "magenta">During this RECITATION, it was **difficult** to **recognize and link the crucial information**.</font>

# %% [markdown]
# 1

# %% [markdown]
# ---
#
#
# ##<font color = "magenta">This RECITATION was often **entertaining**.</font>

# %% [markdown]
# 6

# %% [markdown]
# ---
#
#
# ##<font color = "magenta">I found the **physics** I did in this RECITATION **interesting**.</font>

# %% [markdown]
# 6

# %% [markdown]
# ---
#
#
# ##<font color = "magenta">I **learned valuable things** in this RECITATION.</font><br>

# %% [markdown]
# 6

# %% [markdown]
# # $\color{blue}{\text{PLEASE DO THIS BEFORE THE RECITATION DUE TIME:}}$
#
# ---
#
#
# # $\color{red}{\text{Step 1.	Follow the instructions below on converting this file to a .PDF}}$
# # $\color{red}{\text{Step 2.	Make sure all work and answers are visible in the pdf.}}$
# # $\color{red}{\text{Step 3.	Go to File > Download > .IPYNB file to your computer}}$
# # $\color{green}{\text{Step 4.	Upload on Brightspace (i) .IPYNB file (ii) PDF of this file}}$

# %% [markdown]
# # $\color{red}{\text{  Options to convert to PDF}}$

# %% [markdown]
# ## **Option (i)** Click on 'File' in the top menu and then selecting 'Print', and selecting Save to PDF
#
# * Go to **Print**
# * Select **"Save as PDF"**
# * Go to **"More settings"**
# * Select Paper Size **"A0"**
# ***Adjust the scaling** (about 50%) until you can see all your work and images in the PDF Preview.
# * Select **"Save"**

# %% [markdown]
# ## **Option (ii)** Use the online utility at https://www.vertopal.com/en/convert/ipynb-to-pdf&nbsp;
